# %%
import pyspark
from icecream import ic

# %%
pyspark.sql.SparkSession.active()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pyspark.sql.SparkSession.active()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyspark/sql/utils.py:280, in try_remote_session_classmethod.<locals>.wrapped(*args, **kwargs)
#     278     return getattr(SparkSession, f.__name__)(*args[1:], **kwargs)
#     279 else:
# --> 280     return f(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyspark/sql/session.py:700, in SparkSession.active(cls)
#     686 @classmethod
#     687 @try_remote_session_classmethod
#     688 def active(cls) -> "SparkSession":
#     689     """
#     690     Returns the active or default :class:`SparkSession` for the current thread, returned by
#     691     the builder.
#    (...)
# ...

# %%
# spark.stop()

# %%
spark = pyspark.sql.SparkSession\
        .builder\
        .master("local")\
        .appName("hello-spark")\
        .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.101:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>hello-spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dir(spark)
# Out:
# ['Builder',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activeSession',
#  '_catalog',
#  '_conf',
#  '_convert_from_pandas',
#  '_createFromLocal',
#  '_createFromRDD',
#  '_create_dataframe',
#  '_create_from_pandas_with_arrow',
#  '_create_shell_session',
#  '_getActiveSessionOrCreate',
#  '_get_numpy_record_dtype',
#  '_inferSchema',
#  '_inferSchemaFromList',
#  '_instantiatedSession',
#  '_jconf',
#  '_jsc',
#  '_jsparkSession',
#  '_jvm',
#  '_repr_html_',
#  '_sc',
#  'active',
#  'addArtifact',
#  'addArtifacts',
#  'addTag',
# ...

# %%
ls ../
# Out:
# Coursework/ datasets/

# %%
df  = spark.read\
        .format("csv")\
        .option('header', 'true')\
        .option('inferSchema', 'true')\
        .load('../datasets/Fire_Department_Calls_For_Service__2016__20240712.csv')

# %%
df.show()
# Out:
# +-----------+-------+---------------+----------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+--------------------+-------------+-------------------+---------+------------+----+-----------------+--------+--------------+--------+--------------------+----------------+--------------+------------------------------+------------------------+-------------------+------------------------------------+--------------+
# ...

# %%
df.count()
# Out:
# 2716347

# %%
display(df)
# Out:
# DataFrame[Call Number: int, Unit ID: string, Incident Number: int, Call Date: string, Watch Date: string, Received DtTm: string, Entry DtTm: string, Dispatch DtTm: string, Response DtTm: string, On Scene DtTm: string, Transport DtTm: string, Hospital DtTm: string, Call Final Disposition: string, Available DtTm: string, Address: string, City: string, Zipcode of Incident: double, Battalion: string, Station Area: string, Box: string, Original Priority: string, Priority: string, Final Priority: int, ALS Unit: boolean, Call Type Group: string, Number of Alarms: int, Unit Type: string, Unit sequence in call dispatch: int, Fire Prevention District: string, Supervisor District: string, Neighborhooods - Analysis Boundaries: string, RowID: string]

# %% [markdown]
# **Catalog and Databases in Spark:-**

# %%
ic(spark.catalog.listCatalogs())

ic(spark.catalog.currentCatalog())

ic(spark.catalog.listDatabases())

ic(spark.catalog.currentDatabase())

ic(spark.catalog.listTables())
# Out:
# ic| spark.catalog.listCatalogs(): [CatalogMetadata(name='spark_catalog', description=None)]
# ic| spark.catalog.currentCatalog(): 'spark_catalog'
# ic| spark.catalog.listDatabases(): [Database(name='default', catalog='spark_catalog', description='default database', locationUri='file:/Users/samarth/Desktop/projects/groKPy/sparkey/Coursework/spark-warehouse')]
# ic| spark.catalog.currentDatabase(): 'default'
# ic| spark.catalog.listTables(): []
# []

# %%
spark.catalog.currentDatabase()
# Out:
# 'default'

# %%
df.createOrReplaceGlobalTempView('fire_calls_global')

# spark.range(1).createTempView("local_test_view")

df.createOrReplaceTempView('fire_calls_local')

# %%
spark.catalog.listTables()
# Out:
# [Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
spark.sql('show tables').show()
##here global is not shown...default database doesnt show up as "default" because the name is metaphorical
# Out:
# +---------+----------------+-----------+
# |namespace|       tableName|isTemporary|
# +---------+----------------+-----------+
# |         |fire_calls_local|       true|
# +---------+----------------+-----------+

# %%
spark.catalog.listTables('global_temp')
# Out:
# [Table(name='fire_calls_global', catalog=None, namespace=['global_temp'], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
spark.sql('show tables from global_temp').show()
# Out:
# +-----------+-----------------+-----------+
# |  namespace|        tableName|isTemporary|
# +-----------+-----------------+-----------+
# |global_temp|fire_calls_global|       true|
# |           | fire_calls_local|       true|
# +-----------+-----------------+-----------+

# %%
df2 = df.limit(5)
df2
# Out:
# DataFrame[Call Number: int, Unit ID: string, Incident Number: int, Call Date: string, Watch Date: string, Received DtTm: string, Entry DtTm: string, Dispatch DtTm: string, Response DtTm: string, On Scene DtTm: string, Transport DtTm: string, Hospital DtTm: string, Call Final Disposition: string, Available DtTm: string, Address: string, City: string, Zipcode of Incident: double, Battalion: string, Station Area: string, Box: string, Original Priority: string, Priority: string, Final Priority: int, ALS Unit: boolean, Call Type Group: string, Number of Alarms: int, Unit Type: string, Unit sequence in call dispatch: int, Fire Prevention District: string, Supervisor District: string, Neighborhooods - Analysis Boundaries: string, RowID: string]

# %%
ic(spark.catalog.listTables())
ic(spark.sql('show tables from global_temp').show())
###here df2 is not registered as a table to the Catalog since we didn't createView or createGlovalView
# Out:
# ic| spark.catalog.listTables(): [Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]
# ic| spark.sql('show tables from global_temp').show(): None
# +-----------+-----------------+-----------+
# |  namespace|        tableName|isTemporary|
# +-----------+-----------------+-----------+
# |global_temp|fire_calls_global|       true|
# |           | fire_calls_local|       true|
# +-----------+-----------------+-----------+

# %%
ic(spark.catalog.listDatabases('spark_catalog'),'\n\n\n')
ic(spark.catalog.getTable('fire_calls_local'))
ic(spark.catalog.getTable('spark_catalog.fire_calls_local'))
# Out:
# ic
# | spark.catalog.listDatabases('spark_catalog'): []
#     '\n\n\n': '
#
#
#                '
# ic| spark.catalog.getTable('fire_calls_local'): Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)
# ic| spark.catalog.getTable('spark_catalog.fire_calls_local'): Table(name='fire_calls_local', catalog='spark_catalog', namespace=[], description=None, tableType=None, isTemporary=False)
# Table(name='fire_calls_local', catalog='spark_catalog', namespace=[], description=None, tableType=None, isTemporary=False)

# %%
spark.catalog.getTable('fire_calls_local') is spark.catalog.getTable('spark_catalog.fire_calls_local')
# Out:
# False

# %% [markdown]
# _______

# %% [markdown]
# _______

# %% [markdown]
# _________________

# %% [markdown]
# ***Create Database and Tables***

# %% [markdown]
# how tables are created in spark_warehouse/

# %%
spark.sql('create database my_db')
# Out:
# DataFrame[]

# %%
ic(spark.catalog.listCatalogs())

ic(spark.catalog.currentCatalog())

ic(spark.catalog.listDatabases())

ic(spark.catalog.currentDatabase())

ic(spark.catalog.listTables())
# Out:
# ic| spark.catalog.listCatalogs(): [CatalogMetadata(name='spark_catalog', description=None)]
# ic| spark.catalog.currentCatalog(): 'spark_catalog'
# ic| spark.catalog.listDatabases(): [Database(name='default', catalog='spark_catalog', description='default database', locationUri='file:/Users/samarth/Desktop/projects/groKPy/sparkey/Coursework/spark-warehouse'),
#                                     Database(name='my_db', catalog='spark_catalog', description='', locationUri='file:/Users/samarth/Desktop/projects/groKPy/sparkey/Coursework/spark-warehouse/my_db.db')]
# ic| spark.catalog.currentDatabase(): 'default'
# ic| spark.catalog.listTables(): [Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]
# [Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# creating database my_db using spark.sql and USING keyword :-

# %%
spark.sql("""create table my_db.fire_service_calls_tbl (CallNumber integer, UnitID string, IncidentNumber integer)
          using parquet""")
# Out:
# DataFrame[]

# %%
spark.sql("insert into my_db.fire_service_calls_tbl values(null,null,null )")
# Out:
# DataFrame[]

# %%
spark.sql("select * from my_db.fire_service_calls_tbl").show()
# Out:
# +----------+------+--------------+
# |CallNumber|UnitID|IncidentNumber|
# +----------+------+--------------+
# |      NULL|  NULL|          NULL|
# +----------+------+--------------+

# %%
spark.sql("truncate table my_db.fire_service_calls_tbl")
# Out:
# DataFrame[]

# %%
df2.schema
# Out:
# StructType([StructField('Call Number', IntegerType(), True), StructField('Unit ID', StringType(), True), StructField('Incident Number', IntegerType(), True), StructField('Call Date', StringType(), True), StructField('Watch Date', StringType(), True), StructField('Received DtTm', StringType(), True), StructField('Entry DtTm', StringType(), True), StructField('Dispatch DtTm', StringType(), True), StructField('Response DtTm', StringType(), True), StructField('On Scene DtTm', StringType(), True), StructField('Transport DtTm', StringType(), True), StructField('Hospital DtTm', StringType(), True), StructField('Call Final Disposition', StringType(), True), StructField('Available DtTm', StringType(), True), StructField('Address', StringType(), True), StructField('City', StringType(), True), StructField('Zipcode of Incident', DoubleType(), True), StructField('Battalion', StringType(), True), StructField('Station Area', StringType(), True), StructField('Box', StringType(), True), StructField('
# ...

# %% [markdown]
# Trying the same with pyspark.sql

# %%
spark.catalog.createTable("my_db.fire_service_calls_tbl_using_py", schema=df2.schema, source='parquet')
# Out:
# DataFrame[Call Number: int, Unit ID: string, Incident Number: int, Call Date: string, Watch Date: string, Received DtTm: string, Entry DtTm: string, Dispatch DtTm: string, Response DtTm: string, On Scene DtTm: string, Transport DtTm: string, Hospital DtTm: string, Call Final Disposition: string, Available DtTm: string, Address: string, City: string, Zipcode of Incident: double, Battalion: string, Station Area: string, Box: string, Original Priority: string, Priority: string, Final Priority: int, ALS Unit: boolean, Call Type Group: string, Number of Alarms: int, Unit Type: string, Unit sequence in call dispatch: int, Fire Prevention District: string, Supervisor District: string, Neighborhooods - Analysis Boundaries: string, RowID: string]

# %%
df2.count()

df2.createOrReplaceTempView('df_data_to_insert_into_catalog_table')

# %%
spark.sql("""insert into my_db.fire_service_calls_tbl_using_py
          select * from df_data_to_insert_into_catalog_table
""")
# Out:
# DataFrame[]

# %%
spark.sql("""select count(*) from my_db.fire_service_calls_tbl_using_py""").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |       5|
# +--------+

# %%
spark.sql("""insert into my_db.fire_service_calls_tbl_using_py
          select * from fire_calls_local
""")
# Out:
# DataFrame[]

# %%
spark.sql("""select count(*) from my_db.fire_service_calls_tbl_using_py""").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# | 2716352|
# +--------+

# %%
###creating table in default DB
spark.sql("create table table_in_default_db (id integer, name string) using parquet")
# Out:
# DataFrame[]

# %%
ic(spark.catalog.listTables())
ic(spark.catalog.listTables('my_db'))
# Out:
# ic| spark.catalog.listTables(): [Table(name='table_in_default_db', catalog='spark_catalog', namespace=['default'], description=None, tableType='MANAGED', isTemporary=False),
#                                  Table(name='df_data_to_insert_into_catalog_table', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#                                  Table(name='fire_calls_local', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]
# ic| spark.catalog.listTables('my_db'): [Table(name='fire_service_calls_tbl', catalog='spark_catalog', namespace=['my_db'], description=None, tableType='MANAGED', isTemporary=False),
#                                         Table(name='fire_service_calls_tbl_using_py', catalog='spark_catalog', namespace=['my_db'], description=None, tableType='MANAGED', isTemporary=False),
# ...

# %%
# Out:
# 24/07/13 23:37:36 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 138088 ms exceeds timeout 120000 ms
# 24/07/13 23:37:36 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/07/13 23:37:37 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# ...

# %% [markdown]
# **Input/Output a.k.a read/writer :-**

# %%
spark.sql.DataFrameReader   
# --> doesn't work because DataFrameReader is not under SparkSession!
# it comes under pyspark.sql - i.e., it is a class that exists at the same level as SparkSession!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 spark.sql.DataFrameReader
#
# AttributeError: 'function' object has no attribute 'DataFrameReader'

# %%
dfReader = pyspark.sql.DataFrameReader(spark)

# %%
type(dfReader)
# Out:
# pyspark.sql.readwriter.DataFrameReader

# %%
type(spark.read)
# Out:
# pyspark.sql.readwriter.DataFrameReader

# %%
df = dfReader.csv(path = '../datasets/Fire_Department_Calls_For_Service__2016__20240712.csv')

# %%
df.show()
# Out:
# +-----------+-------+---------------+----------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+-------------------+---------+------------+----+-----------------+--------+--------------+--------+--------------------+----------------+--------------+--------------------+--------------------+-------------------+--------------------+--------------+
# ...

# %%
spark.conf.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 spark.conf()
#
# TypeError: 'RuntimeConfig' object is not callable
